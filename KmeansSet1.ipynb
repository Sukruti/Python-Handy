# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as pltfig

# %%
df = pd.read_excel("C:/Users/adm/Documents/Python Scripts/Dataset/Set1.xls")
df.head()
# Out:
#    A1    A2     A3  A4  A5  A6   A7    A8     A9   A10   A11  Result
# 0  40  1.29   9.99   2  20  74   96  1.28  16.57  4.15  5.69    2331
# 1  26  1.09   8.78   5  12  20   32  1.54  17.60  5.25  6.75    2740
# 2  30  1.36   9.39   5  14  50   64  1.44  17.91  4.87  6.21    2670
# 3  40  1.42  10.40   3  32  84  119  1.34  15.60  3.82  5.83    2390
# 4  24  0.62   8.25   5   8  13   21  1.54  18.16  5.16  6.74    2966

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=4, init='k-means++', n_init=10)

# %%
km.fit(df)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
tr = km.fit_predict(df)
tr
# Out:
# array([0, 3, 3, ..., 0, 0, 0])

# %%
df["Cluster"]= tr
df.head()
# Out:
#    A1    A2     A3  A4  A5  A6   A7    A8     A9   A10   A11  Result  Cluster
# 0  40  1.29   9.99   2  20  74   96  1.28  16.57  4.15  5.69    2331        0
# 1  26  1.09   8.78   5  12  20   32  1.54  17.60  5.25  6.75    2740        3
# 2  30  1.36   9.39   5  14  50   64  1.44  17.91  4.87  6.21    2670        3
# 3  40  1.42  10.40   3  32  84  119  1.34  15.60  3.82  5.83    2390        0
# 4  24  0.62   8.25   5   8  13   21  1.54  18.16  5.16  6.74    2966        1

# %%
df
# Out:
#       A1    A2     A3  A4  A5   A6   A7    A8     A9   A10   A11  Result  \
# 0     40  1.29   9.99   2  20   74   96  1.28  16.57  4.15  5.69    2331
# 1     26  1.09   8.78   5  12   20   32  1.54  17.60  5.25  6.75    2740
# 2     30  1.36   9.39   5  14   50   64  1.44  17.91  4.87  6.21    2670
# 3     40  1.42  10.40   3  32   84  119  1.34  15.60  3.82  5.83    2390
# 4     24  0.62   8.25   5   8   13   21  1.54  18.16  5.16  6.74    2966
# 5     30  1.15   9.31   5  10   41   51  1.44  17.59  4.91  6.25    2811
# 6     45  1.35  10.66   6  35  125  166  1.30  15.63  3.91  5.54    2409
# 7     45  1.27  10.68   5  54  118  177  1.36  15.80  3.40  5.72    2346
# 8     30  1.61   9.27   5  13   41   54  1.44  15.80  3.40  6.26    2702
# 9     40  1.84  10.17   3  33   86  122  1.33  15.80  3.40  5.83    2473
# 10    24  0.64   8.29   5   5    8   13  1.59  17.71  4.51  6.91    2880
# 11    24  1.12   8.25   5   9   13   22  1.54  18.17  4.82  6.77    2847
# 12    30  2.26   9.18   5  11   42   53  1.40  15.80  3.40  6.11    2675
# 13    30  1.23   9.34   5  10   39   49  1.37  16.76  4.29  6.18    2645
# 14    30  1.15   9.22   5  12   33   45  1.40  15.66  3.81  6.26    2554
# 15    30  1.37   9.23   5  12   37   49  1.39  16.78  4.24  6.17    2516
# 2167  40  1.45   9.79   1  19   47   67  1.38  17.10  3.78  6.20    2478
# 2168  45  1.22   9.92   2  18   40   60  1.28  16.48  3.62  5.69    2327
# 2169  40  1.47   9.82   1  20   45   66  1.34  16.78  3.63  6.02    2394
# 2170  30  1.13   9.04   5   9   18   27  1.34  17.52  3.93  6.13    2615
# 2171  45  0.98  10.18   3  24   52   79  1.24  15.99  3.23  5.58    2280
# 2172  40  1.54   9.46   1  17   54   72  1.39  16.42  3.54  6.18    2405
# 2173  45  1.33  10.22   4  21   47   72  1.19  17.18  3.58  5.39    2994
# 2174  40  1.31   9.72   1  17   36   54  1.32  16.49  3.51  5.95    2463
# 2175  45  1.16  10.58   4  33   81  118  1.22  16.74  4.01  5.47    2382
# 2176  45  0.81  10.30   4  23   54   81  1.20  16.67  3.45  5.28    2379
# 2177  40  0.70   9.91   1  16   40   57  1.37  16.84  3.54  6.10    2311
#
#       Cluster
# 0           0
# 1           3
# 2           3
# 3           0
# 4           1
# 5           3
# 6           0
# 7           0
# 8           3
# 9           2
# 10          3
# 11          3
# 12          3
# 13          2
# 14          2
# 15          2
# 16          3
# 17          3
# 18          3
# 19          3
# 20          2
# 21          0
# 22          0
# 23          2
# 24          0
# 25          2
# 26          0
# 27          0
# 28          3
# 29          0
# ...       ...
# 2148        3
# 2149        2
# 2150        0
# 2151        3
# 2152        0
# 2153        2
# 2154        2
# 2155        3
# 2156        2
# 2157        0
# 2158        3
# 2159        2
# 2160        2
# 2161        3
# 2162        2
# 2163        2
# 2164        3
# 2165        0
# 2166        0
# 2167        2
# 2168        0
# 2169        0
# 2170        2
# 2171        0
# 2172        0
# 2173        1
# 2174        2
# 2175        0
# 2176        0
# 2177        0
#
# [2178 rows x 13 columns]

# %%
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
f1=df["A2"].values
f2=df["Cluster"].values
f3=df.index


X = np.array(list(zip(f1,f2)))
X

#plt.scatter(X[:0],X[:2], s=150)
plt.scatter(f2, f3, c='black', s=5)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 'sepal width (cm)'
x_index = 1
# 'petal length (cm)'
y_index = 2

# this formatter will label the colorbar with the correct target names
formatter = plt.FuncFormatter(lambda i, *args: iris.target_names[int(i)])

plt.scatter(iris.data[:, x_index], iris.data[:, y_index],
            c=iris.target, cmap=plt.cm.get_cmap('afmhot', 3))
plt.colorbar(ticks=[0, 1, 2], format=formatter)
plt.clim(-0.5, 2.5)
plt.xlabel(iris.feature_names[x_index])
plt.ylabel(iris.feature_names[y_index]);
# Out:
# array([2.400e+01, 6.400e-01, 8.290e+00, 5.000e+00, 5.000e+00, 8.000e+00,
#        1.300e+01, 1.590e+00, 1.771e+01, 4.510e+00, 6.910e+00, 2.880e+03,
#        3.000e+00])
